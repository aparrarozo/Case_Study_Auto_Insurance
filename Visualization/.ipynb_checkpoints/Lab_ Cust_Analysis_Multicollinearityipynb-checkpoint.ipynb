# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import boxcox

# %%
ca_plotting = pd.read_csv('Data_Marketing_Customer_Analysis_Round2.csv')

# %%
ca_plotting.head()
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# ...

# %%
def drop_columns(ca_plotting) :
    ca_plotting.drop(columns=["Unnamed: 0"], inplace=True)
    return ca_plotting

# %%
drop_columns(ca_plotting)
# Out:
#       Customer       State  Customer Lifetime Value Response  Coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %%
ca_objects = ca_plotting.select_dtypes(include=['object'])

# %%
ca_objects
# Out:
#       Customer       State Response  Coverage Education Effective To Date  \
# 0      DK49336     Arizona       No     Basic   College           2/18/11
# 1      KX64629  California       No     Basic   College           1/18/11
# 2      LZ68649  Washington       No     Basic  Bachelor           2/10/11
# 3      XL78013      Oregon      Yes  Extended   College           1/11/11
# 4      QA50777      Oregon       No   Premium  Bachelor           1/17/11
# ...        ...         ...      ...       ...       ...               ...
# 10905  FE99816      Nevada       No   Premium  Bachelor           1/19/11
# 10906  KX53892      Oregon       No     Basic   College            1/6/11
# 10907  TL39050     Arizona       No  Extended  Bachelor            2/6/11
# 10908  WA60547  California       No   Premium   College           2/13/11
# 10909  IV32877         NaN      NaN     Basic  Bachelor            1/8/11
#
#       EmploymentStatus Gender Location Code Marital Status     Policy Type  \
# ...

# %%
ca_floats = ca_plotting.select_dtypes(include=['float64'])
ca_floats
# Out:
#        Customer Lifetime Value  Months Since Last Claim  \
# 0                  4809.216960                      7.0
# 1                  2228.525238                      3.0
# 2                 14947.917300                     34.0
# 3                 22332.439460                     10.0
# 4                  9025.067525                      NaN
# ...                        ...                      ...
# 10905             15563.369440                      NaN
# 10906              5259.444853                      7.0
# 10907             23893.304100                     11.0
# 10908             11971.977650                      0.0
# 10909              6857.519928                     31.0
#
#        Number of Open Complaints  Total Claim Amount
# 0                            0.0          292.800000
# 1                            0.0          744.924331
# 2                            0.0          480.000000
# 3                            0.0          484.013411
# ...

# %%
ca_integers = ca_plotting.select_dtypes(include=['int64'])

# %%
ca_integers
# Out:
#        Income  Monthly Premium Auto  Months Since Policy Inception  \
# 0       48029                    61                             52
# 1           0                    64                             26
# 2       22139                   100                             31
# 3       49078                    97                              3
# 4       23675                   117                             31
# ...       ...                   ...                            ...
# 10905       0                   253                             40
# 10906   61146                    65                             68
# 10907   39837                   201                             63
# 10908   64195                   158                             27
# 10909       0                   101                              1
#
#        Number of Policies
# 0                       9
# 1                       1
# 2                       2
# 3                       2
# ...

# %%
ca_numerical = pd.concat([ca_integers,ca_floats], axis=1)

# %%
ca_numerical
# Out:
#        Income  Monthly Premium Auto  Months Since Policy Inception  \
# 0       48029                    61                             52
# 1           0                    64                             26
# 2       22139                   100                             31
# 3       49078                    97                              3
# 4       23675                   117                             31
# ...       ...                   ...                            ...
# 10905       0                   253                             40
# 10906   61146                    65                             68
# 10907   39837                   201                             63
# 10908   64195                   158                             27
# 10909       0                   101                              1
#
#        Number of Policies  Customer Lifetime Value  Months Since Last Claim  \
# 0                       9              4809.216960                      7.0
# ...

# %%
plt.figure(figsize=(20,12))
for i, column in enumerate(ca_numerical.columns,1):
    plt.subplot(3,3,i)
    sns.histplot(ca_numerical[column])

# %%
### Normalize data
normalized_numerical=(ca_numerical-ca_numerical.min())/(ca_numerical.max()-ca_numerical.min())

# %%
plt.figure(figsize=(20,12))
for i, column in enumerate(normalized_numerical.columns,1):
    plt.subplot(3,3,i)
    sns.histplot(normalized_numerical[column])

# %%
###Standardize data
z_score_numerical = (ca_numerical-ca_numerical.mean())/ca_numerical.std()

# %%
plt.figure(figsize=(20,12))
for i, column in enumerate(z_score_numerical.columns,1):
    plt.subplot(3,3,i)
    sns.histplot(z_score_numerical[column])

# %%
#detect and remove outliers
# 'Total Claim Amount'

# %%
ca_numerical['Total Claim Amount'].describe()
# Out:
# count    10910.000000
# mean       434.888330
# std        292.180556
# min          0.099007
# 25%        271.082527
# 50%        382.564630
# 75%        547.200000
# max       2893.239678
# Name: Total Claim Amount, dtype: float64

# %%
# Drop the two var that are numerical but cat.

# %%
z_score_numerical.drop(['Number of Open Complaints'], axis=1,inplace=True)

# %%
z_score_numerical
# Out:
#          Income  Monthly Premium Auto  Months Since Policy Inception  \
# 0      0.345619             -0.934776                       0.139870
# 1     -1.236406             -0.847675                      -0.790673
# 2     -0.507170              0.197545                      -0.611722
# 3      0.380172              0.110443                      -1.613846
# 4     -0.456576              0.691121                      -0.611722
# ...         ...                   ...                            ...
# 10905 -1.236406              4.639727                      -0.289611
# 10906  0.777679             -0.818641                       0.712512
# 10907  0.075783              3.129966                       0.533561
# 10908  0.878110              1.881509                      -0.754883
# 10909 -1.236406              0.226579                      -1.685426
#
#        Number of Policies  Customer Lifetime Value  Months Since Last Claim  \
# ...

# %%
z_score_numerical.drop(['Number of Policies'], axis=1,inplace=True)

# %%
z_score_numerical
# Out:
#          Income  Monthly Premium Auto  Months Since Policy Inception  \
# 0      0.345619             -0.934776                       0.139870
# 1     -1.236406             -0.847675                      -0.790673
# 2     -0.507170              0.197545                      -0.611722
# 3      0.380172              0.110443                      -1.613846
# 4     -0.456576              0.691121                      -0.611722
# ...         ...                   ...                            ...
# 10905 -1.236406              4.639727                      -0.289611
# 10906  0.777679             -0.818641                       0.712512
# 10907  0.075783              3.129966                       0.533561
# 10908  0.878110              1.881509                      -0.754883
# 10909 -1.236406              0.226579                      -1.685426
#
#        Customer Lifetime Value  Months Since Last Claim  Total Claim Amount
# ...

# %%
corr=z_score_numerical.iloc[:,0:4].corr()
corr
# Out:
#                                  Income  Monthly Premium Auto  \
# Income                         1.000000             -0.009788
# Monthly Premium Auto          -0.009788              1.000000
# Months Since Policy Inception -0.005903              0.018953
# Customer Lifetime Value        0.028306              0.403069
#
#                                Months Since Policy Inception  \
# Income                                             -0.005903
# Monthly Premium Auto                                0.018953
# Months Since Policy Inception                       1.000000
# Customer Lifetime Value                             0.016960
#
#                                Customer Lifetime Value
# Income                                        0.028306
# Monthly Premium Auto                          0.403069
# Months Since Policy Inception                 0.016960
# Customer Lifetime Value                       1.000000

# %%
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax =plt.subplots(figsize=(9, 7))
    multicollinearity_ax = sns.heatmap(corr, mask=mask, cmap='coolwarm', vmin=-1,vmax=1,annot=True, square=True)

# %%
ca_objects
# Out:
#       Customer       State Response  Coverage Education Effective To Date  \
# 0      DK49336     Arizona       No     Basic   College           2/18/11
# 1      KX64629  California       No     Basic   College           1/18/11
# 2      LZ68649  Washington       No     Basic  Bachelor           2/10/11
# 3      XL78013      Oregon      Yes  Extended   College           1/11/11
# 4      QA50777      Oregon       No   Premium  Bachelor           1/17/11
# ...        ...         ...      ...       ...       ...               ...
# 10905  FE99816      Nevada       No   Premium  Bachelor           1/19/11
# 10906  KX53892      Oregon       No     Basic   College            1/6/11
# 10907  TL39050     Arizona       No  Extended  Bachelor            2/6/11
# 10908  WA60547  California       No   Premium   College           2/13/11
# 10909  IV32877         NaN      NaN     Basic  Bachelor            1/8/11
#
#       EmploymentStatus Gender Location Code Marital Status     Policy Type  \
# ...

# %%
ca_objects['Response'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
Response_graph = ca_objects['Response'].value_counts().plot(kind='bar', color=['purple', 'orange'])

# %%
ca_objects['Sales Channel'].value_counts().plot(kind='bar', color=['brown', 'orange', 'grey', 'beige'])
# Out:
# <AxesSubplot:>

# %%
#Plot of the response rate by the total claim amount.
response_tca = pd.concat([ca_objects['Response'], ca_numerical['Total Claim Amount']], axis=1)
response_tca
# Out:
#       Response  Total Claim Amount
# 0           No          292.800000
# 1           No          744.924331
# 2           No          480.000000
# 3          Yes          484.013411
# 4           No          707.925645
# ...        ...                 ...
# 10905       No         1214.400000
# 10906       No          273.018929
# 10907       No          381.306996
# 10908       No          618.288849
# 10909      NaN         1021.719397
#
# [10910 rows x 2 columns]

# %%
f_resp_tca, ax_resp_tca = plt.subplots(figsize = (5,7))
ax_resp_tca.set_title('response rate by the total claim amount', size='20', fontweight='bold')
sns.barplot(x = response_tca['Response'],y = response_tca['Total Claim Amount'], ax = ax_resp_tca)
# Out:
# <AxesSubplot:title={'center':'response rate by the total claim amount'}, xlabel='Response', ylabel='Total Claim Amount'>

# %%
creativity = pd.concat([ca_objects['Gender'], ca_numerical['Monthly Premium Auto'], ca_numerical['Customer Lifetime Value']], axis=1)
creativity
sns.set_palette('RdYlGn')
palette_alive = {"M": "C5", "F": "C0"}

# %%
fig4, ax4 = plt.subplots(figsize = (12,8))
ax4.set_title('Customer Lifetime Value by Monthly Premium Auto', size='25', fontweight='bold')
sns.scatterplot(x = creativity['Monthly Premium Auto'],y = creativity['Customer Lifetime Value'], 
            hue = creativity['Gender'], ax = ax4, palette=palette_alive)
# Out:
# <AxesSubplot:title={'center':'Customer Lifetime Value by Monthly Premium Auto'}, xlabel='Monthly Premium Auto', ylabel='Customer Lifetime Value'>
